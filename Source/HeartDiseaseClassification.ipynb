# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sns
import matplotlib.pyplot as plt

#dataset from:
#https://www.kaggle.com/datasets/kamilpytlak/personal-key-indicators-of-heart-disease

data1 = pd.read_csv('heart.csv')
data2 = pd.read_csv('heart2.csv')

# %%
print(data1.columns)
#data1
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
print(data2.columns)
data2
# Out:
# Index(['HeartDisease', 'BMI', 'Smoking', 'AlcoholDrinking', 'Stroke',
#        'PhysicalHealth', 'MentalHealth', 'DiffWalking', 'Sex', 'AgeCategory',
#        'Race', 'Diabetic', 'PhysicalActivity', 'GenHealth', 'SleepTime',
#        'Asthma', 'KidneyDisease', 'SkinCancer'],
#       dtype='object')
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0                No  16.60     Yes              No     No             3.0
# 1                No  20.34      No              No    Yes             0.0
# 2                No  26.58     Yes              No     No            20.0
# 3                No  24.21      No              No     No             0.0
# 4                No  23.71      No              No     No            28.0
# ...             ...    ...     ...             ...    ...             ...
# 319790          Yes  27.41     Yes              No     No             7.0
# 319791           No  29.84     Yes              No     No             0.0
# ...

# %%
#print(data1.nunique(axis = 0))

# %%
print(data2.nunique(axis = 0))
# Out:
# HeartDisease           2
# BMI                 3604
# Smoking                2
# AlcoholDrinking        2
# Stroke                 2
# PhysicalHealth        31
# MentalHealth          31
# DiffWalking            2
# Sex                    2
# AgeCategory           13
# Race                   6
# Diabetic               4
# PhysicalActivity       2
# GenHealth              5
# SleepTime             24
# Asthma                 2
# KidneyDisease          2
# SkinCancer             2
# dtype: int64

# %%
#print(data1['target'].value_counts())
#print(data2['HeartDisease'].value_counts())

# %%
cat1 = []
num1 = []
for column in data1.columns:
    if len(data1[column].unique()) <= 10:
        cat1.append(column)
    else:
        num1.append(column)

#print('Categorical: ', cat1)
#print('Continuous: ', num1)

# %%
cat2 = []
num2 = []
for column in data2.columns:
    if len(data2[column].unique()) <= 13:
        cat2.append(column)
    else:
        num2.append(column)

print('Categorical: ', cat2)
print('Continuous: ', num2)
# Out:
# Categorical:  ['HeartDisease', 'Smoking', 'AlcoholDrinking', 'Stroke', 'DiffWalking', 'Sex', 'AgeCategory', 'Race', 'Diabetic', 'PhysicalActivity', 'GenHealth', 'Asthma', 'KidneyDisease', 'SkinCancer']
# Continuous:  ['BMI', 'PhysicalHealth', 'MentalHealth', 'SleepTime']

# %%
'''
df_cat1 = data1.loc[:, cat1]
for i in cat1:
    plt.figure(figsize = (15, 10))
    sns.countplot(x = i, data = df_cat1, palette = "mako")
    plt.title(i)
'''
# Out:
# '\ndf_cat1 = data1.loc[:, cat1]\nfor i in cat1:\n    plt.figure(figsize = (15, 10))\n    sns.countplot(x = i, data = df_cat1, palette = "mako")\n    plt.title(i)\n'

# %%
df_cat2 = data2.loc[:, cat2]
for i in cat2:
    plt.figure(figsize = (15, 10))
    sns.countplot(x = i, data = df_cat2, palette = "mako")
    plt.title(i)

# %%
'''
plt.figure(figsize = (15, 10))
sns.set_context('notebook', font_scale = 1)
sns.heatmap(data1.corr(), annot = True, linewidth = 2)
plt.tight_layout()
'''
# Out:
# "\nplt.figure(figsize = (15, 10))\nsns.set_context('notebook', font_scale = 1)\nsns.heatmap(data1.corr(), annot = True, linewidth = 2)\nplt.tight_layout()\n"

# %%
data2_temp = data2
data2_temp['SkinCancer'] = data2['SkinCancer'].replace(['No', 'Yes'], [0, 1])

plt.figure(figsize = (15, 10))
sns.set_context('notebook', font_scale = 1)
sns.heatmap(data2_temp.corr(), annot = True, linewidth = 2)
plt.tight_layout()

# %% [markdown]
# ## At this point, I decided to discard data set one, since data set two is more than 300 times larger and the two sets don't share any common features.

# %%
df = data2
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319795 entries, 0 to 319794
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   HeartDisease      319795 non-null  object
#  1   BMI               319795 non-null  float64
#  2   Smoking           319795 non-null  object
#  3   AlcoholDrinking   319795 non-null  object
#  4   Stroke            319795 non-null  object
#  5   PhysicalHealth    319795 non-null  float64
#  6   MentalHealth      319795 non-null  float64
#  7   DiffWalking       319795 non-null  object
#  8   Sex               319795 non-null  object
#  9   AgeCategory       319795 non-null  object
#  10  Race              319795 non-null  object
#  11  Diabetic          319795 non-null  object
#  12  PhysicalActivity  319795 non-null  object
#  13  GenHealth         319795 non-null  object
#  14  SleepTime         319795 non-null  float64
# ...

# %%
categorical_dqr = {'Feature': [], 'Desc.':[], 'Count':[], '% of Missing':[], 'Card.':[], 'Mode':[], 'Mode Freq.':[], 'Mode %':[], '2nd Mode':[], '2nd Mode Freq.':[], '2nd Mode %':[], 'Notes':[]}

cat_descriptions = ['Ever reported coronary heart disease (CHD) or myocardial infarction (MI)', 'Smoked at least 100 cigarettes in your life? [Note: 5 packs = 100 cigarettes]', 'Adult men having more than 14 drinks per week and adult women having more than 7 drinks per week', 
                    '(Ever told) (you had) a stroke?', 'Serious difficulty walking or climbing stairs?', 'Male or female?', 'Age category', 'Imputed race/ethnicity value', '(Ever told) (you had) diabetes?', 'Reported physical activity/exercise in the past 30 days, not job', 
                    'Would you say that in general your health is...', '(Ever told) (you had) asthma?', 'Not including kidney stones, bladder infection or incontinence, were you ever told you had kidney disease?', '(Ever told) (you had) skin cancer?']

for i in range(len(cat2)):

    col = df[cat2[i]]
    
    if col.dtype != 'object':
        col = col.astype('object')
      
    col_vals = col.describe()
    counts = col.value_counts()
    counts_index = counts.index
     
    #Feature
    categorical_dqr['Feature'].append(cat2[i])
    #Descriptions
    categorical_dqr['Desc.'].append(cat_descriptions[i])
    #Count
    categorical_dqr['Count'].append(col_vals[0])
    #Percentage of missing values
    categorical_dqr['% of Missing'].append((col.isnull().sum() / col_vals[0])*100)
    #Cardinality
    categorical_dqr['Card.'].append(col.nunique())
    #Mode
    categorical_dqr['Mode'].append(col_vals[2])
    #Mode Freq.
    categorical_dqr['Mode Freq.'].append(col_vals[3])
    #Mode %
    categorical_dqr['Mode %'].append((col_vals[3]/col_vals[0])*100)

    #2nd Mode
    if len(counts_index) > 1:
        categorical_dqr['2nd Mode'].append(counts_index[1])
        #2nd Mode Freq.
        categorical_dqr['2nd Mode Freq.'].append(counts[1])
        #2nd Mode %
        categorical_dqr['2nd Mode %'].append((counts[1] / col_vals[0])*100)
    else:
        categorical_dqr['2nd Mode'].append('Cardinality of 1')
        categorical_dqr['2nd Mode Freq.'].append('Cardinality of 1')
        categorical_dqr['2nd Mode %'].append('Cardinality of 1')
    
    categorical_dqr['Notes'].append('')

dfqr_cat = pd.DataFrame(categorical_dqr)

dfqr_cat
# Out:
#              Feature                                              Desc.  \
# 0       HeartDisease  Ever reported coronary heart disease (CHD) or ...
# 1            Smoking  Smoked at least 100 cigarettes in your life? [...
# 2    AlcoholDrinking  Adult men having more than 14 drinks per week ...
# 3             Stroke                    (Ever told) (you had) a stroke?
# 4        DiffWalking     Serious difficulty walking or climbing stairs?
# 5                Sex                                    Male or female?
# 6        AgeCategory                                       Age category
# 7               Race                       Imputed race/ethnicity value
# 8           Diabetic                    (Ever told) (you had) diabetes?
# 9   PhysicalActivity  Reported physical activity/exercise in the pas...
# 10         GenHealth    Would you say that in general your health is...
# 11            Asthma                      (Ever told) (you had) asthma?
# ...

# %%
dqr_num = {'Feature': [], 'Desc.':[], 'Count':[], '% of Missing':[], 'Card.':[], 'Min.':[], 'Q1':[], 'Median':[], 'Q3':[], 'Max.':[], 'Mean':[], 'Std. Dev.':[], 'Notes':[]}

num_descriptions = ['Body Mass Index (BMI)', 'For how many days during the past 30 was your physical health not good? (0-30 days)', 'For how many days during the past 30 days was your mental health not good? (0-30 days)', 
                    'On average, how many hours of sleep do you get in a 24-hour period?']

for i in range(len(num2)):
    col = df[num2[i]]
    col_vals = col.describe()

    #print('{}\n{}\n'.format(num2[i], num2_name[i]))

    #Feature
    dqr_num['Feature'].append(num2[i])
    
    #Descriptions
    dqr_num['Desc.'].append(num_descriptions[i])
    
    #Count
    dqr_num['Count'].append(col_vals[0])
   
    #Percentage of missing values
    dqr_num['% of Missing'].append(col.isnull().sum() / col_vals[0])
   
    #Cardinality
    dqr_num['Card.'].append(col.nunique())
   
    #Min
    dqr_num['Min.'].append(col_vals[3])
   
    #q1
    dqr_num['Q1'].append(col_vals[4])
   
    #median
    dqr_num['Median'].append(col_vals[5])
   
    #q3
    dqr_num['Q3'].append(col_vals[6])
   
    #max
    dqr_num['Max.'].append(col_vals[7])
   
    #mean
    dqr_num['Mean'].append(col_vals[1])
    
    #STD
    dqr_num['Std. Dev.'].append(col_vals[2])
    
    #Notes
    dqr_num['Notes'].append('')

dfqr_num = pd.DataFrame(dqr_num)

dfqr_num
# Out:
#           Feature                                              Desc.  \
# 0             BMI                              Body Mass Index (BMI)
# 1  PhysicalHealth  For how many days during the past 30 was your ...
# 2    MentalHealth  For how many days during the past 30 days was ...
# 3       SleepTime  On average, how many hours of sleep do you get...
#
#       Count  % of Missing  Card.   Min.     Q1  Median     Q3   Max.  \
# 0  319795.0           0.0   3604  12.02  24.03   27.34  31.42  94.85
# 1  319795.0           0.0     31   0.00   0.00    0.00   2.00  30.00
# 2  319795.0           0.0     31   0.00   0.00    0.00   3.00  30.00
# 3  319795.0           0.0     24   1.00   6.00    7.00   8.00  24.00
#
#         Mean  Std. Dev. Notes
# 0  28.325399   6.356100
# 1   3.371710   7.950850
# 2   3.898366   7.955235
# 3   7.097075   1.436007

# %%
df_drop = df.copy()
df_drop = df_drop.drop_duplicates(ignore_index = True)
drop_percentage = (len(df_drop) / len(df)) * 100

print("Percentage of values left after dropping duplicates: {}".format(drop_percentage))
df_drop.info()
df_drop
# Out:
# Percentage of values left after dropping duplicates: 94.34700354914868
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301717 entries, 0 to 301716
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   HeartDisease      301717 non-null  object
#  1   BMI               301717 non-null  float64
#  2   Smoking           301717 non-null  object
#  3   AlcoholDrinking   301717 non-null  object
#  4   Stroke            301717 non-null  object
#  5   PhysicalHealth    301717 non-null  float64
#  6   MentalHealth      301717 non-null  float64
#  7   DiffWalking       301717 non-null  object
#  8   Sex               301717 non-null  object
#  9   AgeCategory       301717 non-null  object
#  10  Race              301717 non-null  object
#  11  Diabetic          301717 non-null  object
#  12  PhysicalActivity  301717 non-null  object
#  13  GenHealth         301717 non-null  object
# ...

# %%
print(df['SkinCancer'].value_counts())
print(df_drop['SkinCancer'].value_counts())
# Out:
# 0    289976
# 1     29819
# Name: SkinCancer, dtype: int64
# 0    272425
# 1     29292
# Name: SkinCancer, dtype: int64

# %%
final_data = df_drop
final_data.to_csv('heart_clean.csv')
